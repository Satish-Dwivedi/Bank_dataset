# %% [markdown]
# ***Import Libreies***

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Load the Dataset***

# %%
bank_df=pd.read_csv(r"C:\Users\HP\Downloads\corrected_bank_dataset.csv")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ***Data overview in 5 columns***

# %%
bank_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   19   oct        79         1     -1         0  unknown  0
# 1  cellular   11   may       220         1    339         4  failure  0
# 2  cellular   16   apr       185         1    330         1  failure  0
# 3   unknown    3   jun       199         4     -1         0  unknown  0
# 4   unknown    5   may       226         1     -1         0  unknown  0

# %% [markdown]
# ***Drop similar Value columns***

# %%
bank_df.drop('y',axis=1,inplace=True)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ***Data Quick Check***

# %%
bank_df.shape
# Out:
# (4521, 16)

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# ***Seprate Categorical and Numerical***

# %%
cat=bank_df.select_dtypes(include='object').columns
num=bank_df.select_dtypes(exclude='object').columns
print(f"Categorical Columns:{cat}")
print(f"Numerical  Columns:{num}")
# Out:
# Categorical Columns:Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome'],
#       dtype='object')
# Numerical  Columns:Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
cat.size
# Out:
# 9

# %%
num.size
# Out:
# 7

# %%
bank_df['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %% [markdown]
# ***Finding the missing Value***

# %%
print("Check the null Value")
bank_df.isnull().sum()
# Out:
# Check the null Value
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %% [markdown]
# ***Replace duplicates***

# %%
bank_df.drop_duplicates(inplace=False)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ***Categorical Analysis***

# %%
import warnings 
warnings.filterwarnings("ignore")
plt.figure (figsize=(28,8))
for idx,col in enumerate(cat):
    plt.subplot(1,len(cat),idx+1)
    plt.title(col,fontsize=12)
    sns.countplot(data=bank_df,x=col,palette=sns.color_palette("Set2", n_colors=len(bank_df[col].unique())))
    plt.xticks(rotation=45,fontsize=7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 16))  
num_cols = len(cat)
num_rows = (num_cols + 2) // 3  
for idx, col in enumerate(cat):
    plt.subplot(num_rows, 3, idx + 1)  
    plt.title(col, fontsize=9)  
    
    
    plt.pie(
        bank_df[col].value_counts(),
        labels=bank_df[col].value_counts().index,
        autopct="%0.2f%%",
        radius=1.5,
        textprops={'fontsize': 10} )

plt.tight_layout()  
plt.show()

# %% [markdown]
# ***Numerical Analysis***

# %%
plt.figure(figsize=(10,8))
for idx,col in enumerate(num,1):
    plt.subplot(3,3,idx)
    plt.hist(bank_df[col],bins=20,color='pink',edgecolor='black')
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,14))
for idx,col in enumerate(num,1):
    plt.subplot(3,3,idx)
    sns.histplot(bank_df[col],kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
for idx,col in enumerate(num,1):
    plt.subplot(3,3,idx)
    plt.boxplot(bank_df[col],vert=False)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
for i in num:
    q1=np.quantile(bank_df[i],0.25)
    q3=np.quantile(bank_df[i],0.75)
    iqr=q3-q1
    lb=q1-1.5*iqr
    ub=q3+1.5*iqr
    bank_df[i]=bank_df[i].clip(lower=lb,upper=ub)

# %%
plt.boxplot(bank_df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a42bb7af30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a42bb79f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a42bb7baa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a42b9a9fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a42b9a94f0>],
#  'means': []}

# %% [markdown]
# ***Leval Encoading***

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cat:
    bank_df[i]=le.fit_transform(bank_df[i])

bank_df
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      30   10        1          0        0   1787.0        0     0        0
# 1      33    7        1          1        0   3596.5        1     1        0
# 2      35    4        2          2        0   1350.0        1     0        0
# 3      30    4        1          2        0   1476.0        1     1        2
# 4      59    1        1          1        0      0.0        1     0        2
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 4516   33    7        1          1        0   -333.0        1     0        0
# 4517   57    6        1          2        1  -2047.5        1     1        2
# 4518   57    9        1          1        0    295.0        0     0        0
# 4519   28    1        1          1        0   1137.0        0     0        0
# 4520   44    2        2          2        0   1136.0        1     1        0
#
# ...

# %%
X=bank_df.drop('poutcome',axis=1)
y=bank_df['poutcome']

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
sclead=ss.fit_transform(X)
sclead
# Out:
# array([[-1.06791403,  1.71680374, -0.24642938, ..., -0.87120467,
#          0.        ,  0.        ],
#        [-0.77989068,  0.79524562, -0.24642938, ..., -0.87120467,
#          0.        ,  0.        ],
#        [-0.58787512, -0.12631251,  1.42139579, ..., -0.87120467,
#          0.        ,  0.        ],
#        ...,
#        [ 1.52429608,  1.4096177 , -0.24642938, ...,  2.2116979 ,
#          0.        ,  0.        ],
#        [-1.25992959, -1.04787063, -0.24642938, ...,  0.97853687,
#          0.        ,  0.        ],
#        [ 0.27619491, -0.74068459,  1.42139579, ..., -0.25462416,
#          0.        ,  0.        ]])

# %%
scaled_df=pd.DataFrame(sclead,columns=X.columns)
scaled_df['poutcome']=y
scaled_df
# Out:
#            age       job   marital  education   default   balance   housing  \
# 0    -1.067914  1.716804 -0.246429  -1.644755 -0.130759  0.655937 -1.142051
# 1    -0.779891  0.795246 -0.246429  -0.309038 -0.130759  2.114953  0.875617
# 2    -0.587875 -0.126313  1.421396   1.026680 -0.130759  0.303580  0.875617
# 3    -1.067914 -0.126313 -0.246429   1.026680 -0.130759  0.405175  0.875617
# 4     1.716312 -1.047871 -0.246429  -0.309038 -0.130759 -0.784937  0.875617
# ...        ...       ...       ...        ...       ...       ...       ...
# 4516 -0.779891  0.795246 -0.246429  -0.309038 -0.130759 -1.053438  0.875617
# 4517  1.524296  0.488060 -0.246429   1.026680  7.647669 -2.435854  0.875617
# 4518  1.524296  1.409618 -0.246429  -0.309038 -0.130759 -0.547076 -1.142051
# 4519 -1.259930 -1.047871 -0.246429  -0.309038 -0.130759  0.131837 -1.142051
# 4520  0.276195 -0.740685  1.421396   1.026680 -0.130759  0.131030  0.875617
#
# ...

# %% [markdown]
# ***Corelation-plot***

# %%
plt.figure(figsize=(12,4))
sns.heatmap(scaled_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ***Save the EDA file***

# %%
scaled_df.to_csv('bank_preprocess_data',index=False)

# %% [markdown]
# ***ML Model Devlopment***

# %%
bank=pd.read_csv('bank_preprocess_data')
bank
# Out:
#            age       job   marital  education   default   balance   housing  \
# 0    -1.067914  1.716804 -0.246429  -1.644755 -0.130759  0.655937 -1.142051
# 1    -0.779891  0.795246 -0.246429  -0.309038 -0.130759  2.114953  0.875617
# 2    -0.587875 -0.126313  1.421396   1.026680 -0.130759  0.303580  0.875617
# 3    -1.067914 -0.126313 -0.246429   1.026680 -0.130759  0.405175  0.875617
# 4     1.716312 -1.047871 -0.246429  -0.309038 -0.130759 -0.784937  0.875617
# ...        ...       ...       ...        ...       ...       ...       ...
# 4516 -0.779891  0.795246 -0.246429  -0.309038 -0.130759 -1.053438  0.875617
# 4517  1.524296  0.488060 -0.246429   1.026680  7.647669 -2.435854  0.875617
# 4518  1.524296  1.409618 -0.246429  -0.309038 -0.130759 -0.547076 -1.142051
# 4519 -1.259930 -1.047871 -0.246429  -0.309038 -0.130759  0.131837 -1.142051
# 4520  0.276195 -0.740685  1.421396   1.026680 -0.130759  0.131030  0.875617
#
# ...

# %% [markdown]
# ***Split X and y***

# %%
X=bank.drop('poutcome',axis=1)
y=bank['poutcome']
X
# Out:
#            age       job   marital  education   default   balance   housing  \
# 0    -1.067914  1.716804 -0.246429  -1.644755 -0.130759  0.655937 -1.142051
# 1    -0.779891  0.795246 -0.246429  -0.309038 -0.130759  2.114953  0.875617
# 2    -0.587875 -0.126313  1.421396   1.026680 -0.130759  0.303580  0.875617
# 3    -1.067914 -0.126313 -0.246429   1.026680 -0.130759  0.405175  0.875617
# 4     1.716312 -1.047871 -0.246429  -0.309038 -0.130759 -0.784937  0.875617
# ...        ...       ...       ...        ...       ...       ...       ...
# 4516 -0.779891  0.795246 -0.246429  -0.309038 -0.130759 -1.053438  0.875617
# 4517  1.524296  0.488060 -0.246429   1.026680  7.647669 -2.435854  0.875617
# 4518  1.524296  1.409618 -0.246429  -0.309038 -0.130759 -0.547076 -1.142051
# 4519 -1.259930 -1.047871 -0.246429  -0.309038 -0.130759  0.131837 -1.142051
# 4520  0.276195 -0.740685  1.421396   1.026680 -0.130759  0.131030  0.875617
#
# ...

# %% [markdown]
# ***Train-Test-Split***

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((3616, 15), (905, 15), (3616,), (905,))

# %% [markdown]
# ***Without Hyper parameter model***

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, lr_pred)}")
# Out:
# Accuracy: 0.8187845303867404

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
dt_pred =dt_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, lr_pred)}")
# Out:
# Accuracy: 0.8187845303867404

# %% [markdown]
# ***With Hyper parameter***

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT
# Out:
# DecisionTreeClassifier()

# %%
DT.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
para={
     'criterion': ['gini','entropy'],
    'max_depth':[3,4,5,6,7,50],
    'min_samples_split':[2,3,4],
    'min_samples_leaf':[1,2,3,4],
    'random_state':[0,42]}

# %%
grid_search=GridSearchCV(DT,para,scoring='accuracy',cv=5,verbose=True)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 50],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'random_state': [0, 42]},
#              scoring='accuracy', verbose=True)

# %%
import time 
start=time.time()
grid_search.fit(X_train,y_train)
end=time.time()
print("Total time taken is:",(end-start))
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# Total time taken is: 33.90635871887207

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=3,
#                        random_state=0)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'random_state': 0}

# %%
grid_search.best_score_
# Out:
# 0.8194138144471699

# %%
from sklearn.metrics import accuracy_score
DT.fit(X_train,y_train)
grid_tree=DT.predict(X_test)
Accuracy_DT=accuracy_score(y_test,grid_tree)
print("Accuracy Score:",Accuracy_DT)
# Out:
# Accuracy Score: 0.7314917127071823

# %%
import pickle as pkl

# %%
with open ('bank_data set.pkl','wb') as file:
    pkl.dump(DT,file)
